# %%
from textblob import TextBlob
import pandas as pd

# %%
reviews = [
    "This movie was amazing and fantastic",
    "I loved this film",
    "Excellent acting and great story",
    "This movie was terrible",
    "Worst movie ever",
    "The story was boring and disappointing",
    "It was okay",
    "Not bad but not great"
]

# %%
results = []

for review in reviews:
    polarity = TextBlob(review).sentiment.polarity

    if polarity > 0:
        sentiment = "Positive"
    elif polarity < 0:
        sentiment = "Negative"
    else:
        sentiment = "Neutral"

    results.append([review, sentiment])

df = pd.DataFrame(results, columns=["Review", "Sentiment"])

df
# Out:
#                                    Review Sentiment
# 0    This movie was amazing and fantastic  Positive
# 1                       I loved this film  Positive
# 2        Excellent acting and great story  Positive
# 3                 This movie was terrible  Negative
# 4                        Worst movie ever  Negative
# 5  The story was boring and disappointing  Negative
# 6                             It was okay  Positive
# 7                   Not bad but not great  Negative

# %%
print(df["Sentiment"].value_counts())
# Out:
# Sentiment
# Positive    4
# Negative    4
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

df["Sentiment"].value_counts().plot(
    kind="pie",
    autopct="%1.1f%%"
)

plt.title("Sentiment Analysis Results")
plt.ylabel("")

plt.savefig("sentiment_pie_chart.png")
plt.show()

# %% [markdown]
# # Sentiment Analysis Project
#
# ### CodeAlpha Data Analytics Internship
#
# **Author:** Harshit
#
# ### Objective
#
# To analyze text reviews and classify them into Positive, Negative, and Neutral sentiments using Natural Language Processing (NLP).
#
# ### Tools Used
#
# - Python
# - TextBlob
# - Pandas
# - Matplotlib
# - Jupyter Notebook
#
# ### Analysis Performed
#
# - Text preprocessing
# - Sentiment classification
# - Sentiment distribution visualization
#
# ### Key Findings
#
# - Positive reviews showed higher polarity scores.
# - Negative reviews showed lower polarity scores.
# - Reviews were successfully categorized into sentiment groups.
#
# ### Conclusion
#
# Sentiment Analysis helps understand opinions and emotions expressed in text data. This project demonstrates the use of NLP techniques to classify customer or user reviews into meaningful categories.
